# %% [markdown]
# importando o pandas para meu codigo

# %%
import pandas as pd

# %% [markdown]
# colocando o arquivo rating no meu programa

# %%
notas = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/ratings.csv')
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.shape #retorna quantidade de informações e colunas
# Out:
# (100836, 4)

# %%
notas.columns = ['usuarioId', 'filmeId', 'nota', 'momento'] #trocando o nome das colunas
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota'].unique() # retorna os valores unicos na coluna nota
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota'].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas['nota'].mean()
# Out:
# 3.501556983616962

# %%
notas['nota'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas['nota'].median()
# Out:
# 3.5

# %%
mediana = notas['nota'].median()
media = notas['nota'].mean()
print(f'Mediana é {mediana} e a média é {media}')
# Out:
# Mediana é 3.5 e a média é 3.501556983616962

# %%
notas['nota'].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %% [markdown]
# importando seaborn para analise com outros gráficos

# %%
import seaborn as sns

# %%
sns.boxplot(notas['nota'])
# Out:
# <Axes: ylabel='nota'>

# %%
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/movies.csv")
filmes.columns = ['filmeId', 'titulo', 'genero']
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# filme Toy Story
notas.query("filmeId == 1")['nota'].mean()
# Out:
# 3.9209302325581397

# %%
#filme jumanji
notas.query("filmeId == 2")['nota'].mean()
# Out:
# 3.4318181818181817

# %%
# agrupando os valores através dos filmes
medias_por_filme = notas.groupby('filmeId')['nota'].mean()
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='nota'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
import matplotlib.pyplot as plt

sns.displot(medias_por_filme, kde=True)
plt.title('Histogramas média dos filmes')
# Out:
# Text(0.5, 1.0, 'Histogramas média dos filmes')

# %%
tmdb = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/tmdb_5000_movies.csv')
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
sns.displot(tmdb['revenue'])
plt.title('Receitas dos Filmes')
plt.show()

# %%
sns.displot(tmdb['budget'])
plt.title('Distribuição do orçamento dos filmes')
plt.show()

# %%
tmdb.info() #retorna o tipo da coluna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
com_faturamento = tmdb.query('revenue > 0')
sns.displot(com_faturamento['revenue'])

# %%
tmdb['original_language'].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb['original_language'].value_counts()
# Out:
# original_language
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: count, dtype: int64

# %%
contagem_linguas = tmdb['original_language'].value_counts().to_frame().reset_index() #transforma a coluna em um dataframe
contagem_linguas.columns = ['original_language', 'total']
contagem_linguas.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(data=contagem_linguas, x= 'original_language', y='total')
# Out:
# <Axes: xlabel='original_language', ylabel='total'>

# %%
sns.countplot(data=tmdb, x='original_language') #gráfico sem ter que fazer muita limpeza
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
contagem_linguas.plot(kind='pie', y='total', labels=contagem_linguas['original_language'])
# Out:
# <Axes: ylabel='total'>

# %%
total_por_lingua = tmdb[ 'original_language'].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc['en'] # para localizar uma informação na coluna
total_do_resto = total_geral - total_de_ingles

# %%
dados = {
    "lingua": ['ingles', 'outros'],
    'total': [total_de_ingles, total_do_resto]
}
dados = pd.DataFrame(dados) # criando um dataframe para visualizar as informações
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(data=dados, x='lingua', y='total')
plt.title('Total de filmes por lingua')
plt.show()

# %%
total_outros_lingua = tmdb.query('original_language != "en"')['original_language'].value_counts()
total_outros_lingua.head()
# Out:
# original_language
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# Name: count, dtype: int64

# %%
sns.countplot(data=tmdb.query('original_language != "en"'), x='original_language')
plt.title('Total de filmes sem ingles')
plt.show()

# %%
sns.countplot(data=tmdb.query('original_language != "en"'), x='original_language', order=total_outros_lingua.index)
plt.title('Total de filmes sem ingles')
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(data=tmdb.query('original_language != "en"'), x='original_language', order=total_outros_lingua.index, palette='crest', hue_order=total_outros_lingua.index, hue='original_language', stat='percent')
plt.title('Total de filmes sem ingles')
plt.show()

# %%
import numpy as np

filme1 = [2.5] * 10 + [3.5] * 10
np.mean(filme1)
# Out:
# 3.0

# %%
filme2 = [5] * 10 + [1] * 10
np.mean(filme2)
# Out:
# 3.0

# %%
media_filme1 = np.mean(filme1)
mediana_filme1 = np.median(filme1)

media_filme2 = np.mean(filme2)
mediana_filme2 = np.median(filme2)

print(f'Filme 1: \nMédia: {media_filme1} \nMediana: {mediana_filme1}')
print(f'\nFilme 2: \nMédia: {media_filme2} \nMediana: {mediana_filme2}')
# Out:
# Filme 1:
# Média: 3.0
# Mediana: 3.0
#
# Filme 2:
# Média: 3.0
# Mediana: 3.0

# %%
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot([filme1, filme2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b524f2daf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b524f2df70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b524f2d820>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2b524f2e510>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2b524f2e780>,
# ...
#  'means': []}

# %%
filme0 = [3] * 20
media_filme0 = np.mean(filme0)

# %%
np.std(filme0), np.std(filme1), np.std(filme2)
# Out:
# (0.0, 0.5, 2.0)
